# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("./fracture.csv")
df.sample(5)
# Out:
#         id sex  fracture  duration  age    wt     ht   bmi  Tscores  fnbmd  \
# 965   2859   M         0     13.21   70  76.0  173.0  25.0     2.67   1.36
# 1617  6118   F         0      9.78   64  76.0  168.0  27.0    -0.67   0.92
# 2086  9497   F         1      0.10   77  78.0  157.0  32.0      NaN    NaN
# 1106  3291   M         0      7.84   74  66.0  173.0  22.0    -2.08   0.79
# 987   2946   M         0     12.44   69  70.0  165.0  26.0    -0.50   0.98
#
#       lsbmd  fall  priorfracture  death
# 965   1.691     0              0      0
# 1617  1.014     1              0      1
# 2086    NaN     0              0      0
# 1106  1.258     0              0      0
# 987   1.356     0              0      1

# %%
df_cleanNaN = df.dropna()
dummi = pd.get_dummies(df_cleanNaN, drop_first=True)
dummi.sample(5)
# Out:
#         id  fracture  duration  age     wt     ht   bmi  Tscores  fnbmd  \
# 1049  3110         0     13.37   63   63.0  154.0  27.0     0.17   1.02
# 2165  9647         1      0.10   78   90.0  181.0  27.0    -1.42   0.87
# 463   1216         0     14.59   78   70.0  175.0  23.0    -1.75   0.83
# 1555  6030         0     14.41   68   72.0  159.0  28.0    -1.50   0.82
# 973   2893         0      3.54   74  102.0  154.0  43.0    -1.75   0.79
#
#       lsbmd  fall  priorfracture  death  sex_M
# 1049  0.951     0              0      0  False
# 2165  1.507     0              0      0   True
# 463   1.264     0              0      1   True
# 1555  0.977     0              0      0  False
# 973   1.349     2              0      0  False

# %%
X_train, X_test, y_train, y_test = train_test_split(dummi.drop(columns="fracture"), dummi["fracture"])
X_train.sample(5)
# Out:
#         id  duration  age    wt     ht   bmi  Tscores  fnbmd  lsbmd  fall  \
# 2127  9569      1.47   76  80.0  166.0  29.0    -1.33   0.84  1.051     0
# 867   2472      7.82   65  63.0  167.0  23.0    -1.42   0.83  1.097     0
# 1868  9054      0.73   76  47.0  162.0  18.0    -5.83   0.34  0.910     0
# 431   1126     13.12   68  73.0  155.0  30.0    -1.67   0.80  0.680     0
# 339    839     13.36   64  68.0  172.0  23.0    -2.92   0.69  1.099     0
#
#       priorfracture  death  sex_M
# 2127              0      1  False
# 867               0      0  False
# 1868              1      1   True
# 431               0      1  False
# 339               0      0   True

# %%
pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=500)
)

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=500))])

# %%
y_pred = pipeline.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc:.2%}")
# Out:
# Accuracy: 82.25%
